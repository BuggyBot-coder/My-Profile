# %%
import pandas as pd

# %%
data=pd.read_csv(r"loan approval.csv")

# %%
data
# Out:
#    Applicant_ID  Income ($)  Credit Score  Loan Amount ($)  \
# 0           101       50000           720            15000
# 1           102       30000           650            10000
# 2           103       75000           800            20000
# 3           104       40000           600            12000
# 4           105       90000           750            25000
# 5           106       20000           550             5000
# 6           107       65000           780            18000
# 7           108       55000           710            16000
# 8           109       38000           590            10000
# 9           110       85000           770            22000
#
#    Loan Term (Months) Employment Type  Debt-to-Income Ratio (%)  \
# 0                  36        Salaried                        25
# 1                  48   Self-Employed                        35
# 2                  24        Salaried                        20
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encode=LabelEncoder()

# %%
encode
# Out:
# LabelEncoder()

# %%
data[["Employment Type","Previous Defaults"]]=data[["Employment Type","Previous Defaults"]].apply(encode.fit_transform)

# %%
data
# Out:
#    Applicant_ID  Income ($)  Credit Score  Loan Amount ($)  \
# 0           101       50000           720            15000
# 1           102       30000           650            10000
# 2           103       75000           800            20000
# 3           104       40000           600            12000
# 4           105       90000           750            25000
# 5           106       20000           550             5000
# 6           107       65000           780            18000
# 7           108       55000           710            16000
# 8           109       38000           590            10000
# 9           110       85000           770            22000
#
#    Loan Term (Months)  Employment Type  Debt-to-Income Ratio (%)  \
# 0                  36                1                        25
# 1                  48                2                        35
# 2                  24                1                        20
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x=data[["Applicant_ID","Income ($)","Credit Score","Loan Amount ($)","Loan Term (Months)","Employment Type","Debt-to-Income Ratio (%)","Previous Defaults"]]

# %%
y=data["Loan Approved (Yes=1, No=0)"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=42)

# %%
x
# Out:
#    Applicant_ID  Income ($)  Credit Score  Loan Amount ($)  \
# 0           101       50000           720            15000
# 1           102       30000           650            10000
# 2           103       75000           800            20000
# 3           104       40000           600            12000
# 4           105       90000           750            25000
# 5           106       20000           550             5000
# 6           107       65000           780            18000
# 7           108       55000           710            16000
# 8           109       38000           590            10000
# 9           110       85000           770            22000
#
#    Loan Term (Months)  Employment Type  Debt-to-Income Ratio (%)  \
# 0                  36                1                        25
# 1                  48                2                        35
# 2                  24                1                        20
# ...

# %%
x_test
# Out:
#    Applicant_ID  Income ($)  Credit Score  Loan Amount ($)  \
# 8           109       38000           590            10000
#
#    Loan Term (Months)  Employment Type  Debt-to-Income Ratio (%)  \
# 8                  60                1                        38
#
#    Previous Defaults
# 8                  1

# %%
y_train
# Out:
# 1    0
# 5    0
# 0    1
# 7    1
# 2    1
# 9    1
# 4    1
# 3    0
# 6    1
# Name: Loan Approved (Yes=1, No=0), dtype: int64

# %%
y_test
# Out:
# 8    0
# Name: Loan Approved (Yes=1, No=0), dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()

# %%
#model.fit(x_test,y_test)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
x_test.sample()
# Out:
#    Applicant_ID  Income ($)  Credit Score  Loan Amount ($)  \
# 8           109       38000           590            10000
#
#    Loan Term (Months)  Employment Type  Debt-to-Income Ratio (%)  \
# 8                  60                1                        38
#
#    Previous Defaults
# 8                  1

# %%
model.predict(x_test.iloc[0].values.reshape(1,-1))
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
import numpy as np

# %%
x_test
# Out:
#    Applicant_ID  Income ($)  Credit Score  Loan Amount ($)  \
# 8           109       38000           590            10000
#
#    Loan Term (Months)  Employment Type  Debt-to-Income Ratio (%)  \
# 8                  60                1                        38
#
#    Previous Defaults
# 8                  1

# %%
x1=np.array([105,95000,650,10000,60,1,38,0])

# %%
x1=x1.reshape(1,-1)

# %% [markdown]
# ### model.predict(x1)

# %%
model.predict(x1)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])
